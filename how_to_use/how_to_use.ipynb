# %%
import sys
import os
import numpy as np
from sentence_transformers import SentenceTransformer

# Add the project root to Python path and change to parent directory
project_root = '/home/ubuntu/ilab_stuff/fine-tuned-hybrid-rag'
os.chdir(project_root)
sys.path.append(project_root)

from retrieval.hybrid_retriever import load_retrieval_components, hybrid_retrieve

print("Imports successful")
print(f"Current working directory: {os.getcwd()}")
# Out:
# Imports successful
# Current working directory: /home/ubuntu/ilab_stuff/fine-tuned-hybrid-rag

# %%
# Load base components (uses base model and embeddings)
print("Loading base retrieval components...")
base_components = load_retrieval_components()

print(f"Loaded {len(base_components['documents'])} documents")
print(f"Dense embeddings shape: {base_components['dense_embeddings'].shape}")
print(f"TF-IDF vocabulary size: {len(base_components['tfidf_vectorizer'].vocabulary_)}")
print(f"Base model: {base_components['model_name']}")
print(f"Device: {base_components['device']}")
# Out:
# Loading base retrieval components...
# Loading hybrid retrieval components...
# Loading dense embeddings from embeddings/dense.npy...
# Loaded dense embeddings shape: (889289, 384)
# Loading TF-IDF vectorizer from embeddings/tfidf_vectorizer.pkl...
# TF-IDF vocabulary size: 10000
# Loading documents from data/processed_docs.jsonl...
# Loading documents: 889289it [00:29, 29726.11it/s]
# Loaded 889289 documents
# Loading sentence transformer model: sentence-transformers/all-MiniLM-L6-v2
# Using device: cuda
# All components loaded successfully!
# Loaded 889289 documents
# Dense embeddings shape: (889289, 384)
# TF-IDF vocabulary size: 10000
# Base model: sentence-transformers/all-MiniLM-L6-v2
# Device: cuda

# %%
# Example query - using metadata-rich format that matches evaluation
query = "what is machine learning"

print(f"Query: '{query}'")
print(f"Searching with base model...")

# Retrieve with base model
base_results = hybrid_retrieve(
    query=query,
    components=base_components,
    top_k=5
)

print(f"\n=== BASE MODEL RESULTS (Top 5) ===")
for i, doc in enumerate(base_results):
    print(f"\n{i+1}. Title: {doc['metadata']['title'][:80]}...")
    print(f"   Final Score: {doc['scores']['final_score']:.4f}")
    print(f"   Dense: {doc['scores']['dense_score']:.4f} | Sparse: {doc['scores']['sparse_score']:.4f} | Boost: {doc['scores']['boost_score']:.4f}")
    if 'year' in doc['metadata']:
        print(f"   Year: {doc['metadata']['year']} | Venue: {doc['metadata'].get('venue', 'N/A')}")
# Out:
# Query: 'what is machine learning'
# Searching with base model...
# Retrieving top-5 documents for query: 'what is machine learning...'
# Encoding query...
# Computing dense similarities (top-1000)...
# Computing sparse similarities...
# Applying metadata boosting...
# Combining scores...
# Retrieved 5 documents
#
# === BASE MODEL RESULTS (Top 5) ===
#
# 1. Title: Will Skynet Need a Librarian? A Literature Review of Machine Learning–Based Data...
#    Final Score: 0.7191
#    Dense: 0.6086 | Sparse: 0.8464 | Boost: 1.0000
#    Year: 2018 | Venue:
#
# 2. Title: The papers of this issue on machine learning: editorial...
#    Final Score: 0.6976
#    Dense: 0.6380 | Sparse: 0.7160 | Boost: 1.0000
#    Year: 1987 | Venue: Comput. Intell.
#
# 3. Title: Role of Intelligent Machines learning for the Successful Implementation of Busin...
#    Final Score: 0.6872
#    Dense: 0.6116 | Sparse: 0.7342 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 4. Title: Machine Learning for IoT...
#    Final Score: 0.6871
#    Dense: 0.6218 | Sparse: 0.7134 | Boost: 1.0000
#    Year: 2020 | Venue:
#
# 5. Title: Mastering machine learning with scikit-learn : apply effective learning algorith...
#    Final Score: 0.6762
#    Dense: 0.5843 | Sparse: 0.7522 | Boost: 1.0000
#    Year: 2014 | Venue:

# %%
# Load fine-tuned components
print("Loading fine-tuned components...")

# Start with base components
ft_components = load_retrieval_components()

# Replace with fine-tuned model and embeddings
config = ft_components['config']
ft_model_path = config['finetune']['output_path']
ft_embeddings_path = config['embeddings']['dense_finetuned_path']

print(f"Loading fine-tuned model from: {ft_model_path}")
print(f"Loading fine-tuned embeddings from: {ft_embeddings_path}")

# Load fine-tuned model
ft_components['sentence_model'] = SentenceTransformer(ft_model_path)

# Load fine-tuned embeddings
ft_components['dense_embeddings'] = np.load(ft_embeddings_path)

print(f"Fine-tuned model loaded")
print(f"Fine-tuned embeddings shape: {ft_components['dense_embeddings'].shape}")
print(f"Ready for improved retrieval!")
# Out:
# Loading fine-tuned components...
# Loading hybrid retrieval components...
# Loading dense embeddings from embeddings/dense.npy...
# Loaded dense embeddings shape: (889289, 384)
# Loading TF-IDF vectorizer from embeddings/tfidf_vectorizer.pkl...
# TF-IDF vocabulary size: 10000
# Loading documents from data/processed_docs.jsonl...
# Loading documents: 889289it [00:44, 20102.11it/s]
# Loaded 889289 documents
# Loading sentence transformer model: sentence-transformers/all-MiniLM-L6-v2
# Using device: cuda
# All components loaded successfully!
# Loading fine-tuned model from: finetune/model/
# Loading fine-tuned embeddings from: embeddings/dense_finetuned.npy
# Fine-tuned model loaded
# Fine-tuned embeddings shape: (889289, 384)
# Ready for improved retrieval!

# %%
# Same query with fine-tuned model
query = "what is machine learning"
print(f"Query: '{query}'")
print(f"Searching with fine-tuned model...")

ft_results = hybrid_retrieve(
    query=query,
    components=ft_components,
    top_k=100
)

print(f"\n=== FINE-TUNED MODEL RESULTS (Top 5) ===")
for i, doc in enumerate(ft_results):
    print(f"\n{i+1}. Title: {doc['metadata']['title'][:80]}...")
    print(f"   Final Score: {doc['scores']['final_score']:.4f}")
    print(f"   Dense: {doc['scores']['dense_score']:.4f} | Sparse: {doc['scores']['sparse_score']:.4f} | Boost: {doc['scores']['boost_score']:.4f}")
    if 'year' in doc['metadata']:
        print(f"   Year: {doc['metadata']['year']} | Venue: {doc['metadata'].get('venue', 'N/A')}")
# Out:
# Query: 'what is machine learning'
# Searching with fine-tuned model...
# Retrieving top-100 documents for query: 'what is machine learning...'
# Encoding query...
# Computing dense similarities (top-1000)...
# Computing sparse similarities...
# Applying metadata boosting...
# Combining scores...
# Retrieved 100 documents
#
# === FINE-TUNED MODEL RESULTS (Top 5) ===
#
# 1. Title: Machine Learning for IoT...
#    Final Score: 0.7834
#    Dense: 0.7823 | Sparse: 0.7134 | Boost: 1.0000
#    Year: 2020 | Venue:
#
# 2. Title: Machine Learning Techniques for Wireless-Powered Ambient Backscatter Communicati...
#    Final Score: 0.7776
#    Dense: 0.7479 | Sparse: 0.7630 | Boost: 1.0000
#    Year: 2020 | Venue: Convergence of Artificial Intelligence and the Internet of Things
#
# 3. Title: Machine learning in the optimization of robotics in the operative field...
#    Final Score: 0.7762
#    Dense: 0.7648 | Sparse: 0.7246 | Boost: 1.0000
#    Year: 2020 | Venue: Current opinion in urology
#
# 4. Title: Machine Learning Applications to Resting-State Functional MR Imaging Analysis....
#    Final Score: 0.7669
#    Dense: 0.7373 | Sparse: 0.7483 | Boost: 1.0000
#    Year: 2017 | Venue: Neuroimaging clinics of North America
#
# 5. Title: A study on machine learning web service...
#    Final Score: 0.7622
#    Dense: 0.7181 | Sparse: 0.7711 | Boost: 1.0000
#    Year: 2017 | Venue: 2017 International Conference on Information and Communication Technology Convergence (ICTC)
#
# 6. Title: Machine Learning in LacePro Multi-Functional Framework...
#    Final Score: 0.7612
#    Dense: 0.8048 | Sparse: 0.5943 | Boost: 1.0000
#    Year: 1997 | Venue:
#
# 7. Title: Machine Learning for Mathematical Software...
#    Final Score: 0.7602
#    Dense: 0.7787 | Sparse: 0.6432 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 8. Title: Machine Learning Algorithms for Stratigraphy Classification on Uranium Deposits...
#    Final Score: 0.7576
#    Dense: 0.7889 | Sparse: 0.6142 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 9. Title: Machine Learning Applied to Sensor Data Analysis: Part 2...
#    Final Score: 0.7538
#    Dense: 0.7625 | Sparse: 0.6543 | Boost: 1.0000
#    Year: 2017 | Venue:
#
# 10. Title: Machine learning algorithm for automatic labeling and its application in text-to...
#    Final Score: 0.7457
#    Dense: 0.8375 | Sparse: 0.4773 | Boost: 1.0000
#    Year: 2006 | Venue:
#
# 11. Title: Machine learning study of several classifiers trained with texture analysis feat...
#    Final Score: 0.7453
#    Dense: 0.8107 | Sparse: 0.5298 | Boost: 1.0000
#    Year: 2010 | Venue: Journal of magnetic resonance imaging : JMRI
#
# 12. Title: Machine Learning in Automation...
#    Final Score: 0.7390
#    Dense: 0.7764 | Sparse: 0.5771 | Boost: 1.0000
#    Year: 2018 | Venue: Autom.
#
# 13. Title: Machine learning in motion analysis: New advances...
#    Final Score: 0.7380
#    Dense: 0.7776 | Sparse: 0.5716 | Boost: 1.0000
#    Year: 2013 | Venue: Image Vis. Comput.
#
# 14. Title: Machine learning for natural language processing (and vice versa...
#    Final Score: 0.7340
#    Dense: 0.7221 | Sparse: 0.6692 | Boost: 1.0000
#    Year: 2005 | Venue:
#
# 15. Title: A Machine Learning Approach to Musical Style Recognition...
#    Final Score: 0.7323
#    Dense: 0.8306 | Sparse: 0.4463 | Boost: 1.0000
#    Year: 1997 | Venue: ICMC
#
# 16. Title: A machine learning approach for the prediction of settling velocity...
#    Final Score: 0.7254
#    Dense: 0.8179 | Sparse: 0.4488 | Boost: 1.0000
#    Year: 2014 | Venue:
#
# 17. Title: Machine learning as a design material: a curated collection of exemplars for vis...
#    Final Score: 0.7231
#    Dense: 0.7819 | Sparse: 0.5132 | Boost: 1.0000
#    Year: 2018 | Venue:
#
# 18. Title: A machine learning methodology to predict alerts and maintenance interventions i...
#    Final Score: 0.7224
#    Dense: 0.8749 | Sparse: 0.3247 | Boost: 1.0000
#    Year: 2020 | Venue:
#
# 19. Title: A Study on Machine Learning Algorithms for Fall Detection and Movement Classific...
#    Final Score: 0.7216
#    Dense: 0.8200 | Sparse: 0.4321 | Boost: 1.0000
#    Year: 2011 | Venue: 2011 International Conference on Information Science and Applications
#
# 20. Title: Machine Learning Techniques for Analyzing Training Behavior in Serious Gaming...
#    Final Score: 0.7183
#    Dense: 0.7621 | Sparse: 0.5368 | Boost: 1.0000
#    Year: 2019 | Venue: IEEE Transactions on Games
#
# 21. Title: MACHINE LEARNING FRAMEWORK FOR PRIORITIZING LOCATION MEASUREMENTS OF MULTIPLE DE...
#    Final Score: 0.7161
#    Dense: 0.7761 | Sparse: 0.5016 | Boost: 1.0000
#    Year: 2018 | Venue:
#
# 22. Title: Machine Learning for Coreference Resolution : Recent Developments...
#    Final Score: 0.7158
#    Dense: 0.7712 | Sparse: 0.5101 | Boost: 1.0000
#    Year: 2007 | Venue:
#
# 23. Title: Machine learning and statistical techniques. An application to the prediction of...
#    Final Score: 0.7081
#    Dense: 0.7685 | Sparse: 0.4901 | Boost: 1.0000
#    Year: 2005 | Venue:
#
# 24. Title: Machine learning-assisted directed protein evolution with combinatorial librarie...
#    Final Score: 0.7050
#    Dense: 0.7162 | Sparse: 0.5843 | Boost: 1.0000
#    Year: 2019 | Venue: Proceedings of the National Academy of Sciences
#
# 25. Title: How Machine Learning Is Revolutionizing Healthcare...
#    Final Score: 0.7031
#    Dense: 0.6538 | Sparse: 0.7028 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 26. Title: A machine learning approach to error detection and recovery in assembly...
#    Final Score: 0.7027
#    Dense: 0.8182 | Sparse: 0.3725 | Boost: 1.0000
#    Year: 1995 | Venue: Proceedings 1995 IEEE/RSJ International Conference on Intelligent Robots and Systems. Human Robot Interaction and Cooperative Robots
#
# 27. Title: Machine learning based detection of Kepler objects of interest...
#    Final Score: 0.6986
#    Dense: 0.7490 | Sparse: 0.4972 | Boost: 1.0000
#    Year: 2017 | Venue:
#
# 28. Title: Machine Learning Models of Acute Kidney Injury Prediction in Acute Pancreatitis ...
#    Final Score: 0.6960
#    Dense: 0.7661 | Sparse: 0.4547 | Boost: 1.0000
#    Year: 2020 | Venue: Gastroenterology research and practice
#
# 29. Title: A Machine Learning Perspective for the Semantic Web...
#    Final Score: 0.6947
#    Dense: 0.7917 | Sparse: 0.3991 | Boost: 1.0000
#    Year: 2001 | Venue:
#
# 30. Title: Machine learning meets pK a...
#    Final Score: 0.6933
#    Dense: 0.7364 | Sparse: 0.5047 | Boost: 1.0000
#    Year: 2020 | Venue: F1000Research
#
# 31. Title: Machine Learning Challenges for Single Cell Data...
#    Final Score: 0.6926
#    Dense: 0.7155 | Sparse: 0.5442 | Boost: 1.0000
#    Year: 2016 | Venue: ECML/PKDD
#
# 32. Title: Machine learning and windowed subsecond event detection on PMU data via Hadoop a...
#    Final Score: 0.6923
#    Dense: 0.7656 | Sparse: 0.4431 | Boost: 1.0000
#    Year: 2010 | Venue: IEEE PES General Meeting
#
# 33. Title: Machine Learning of Physics Word Problems: A Preliminary Report...
#    Final Score: 0.6923
#    Dense: 0.6720 | Sparse: 0.6304 | Boost: 1.0000
#    Year: 1998 | Venue:
#
# 34. Title: A Machine Learning Approach to Upscale Net Ecosystem Exchange to a Regional Scal...
#    Final Score: 0.6922
#    Dense: 0.8119 | Sparse: 0.3501 | Boost: 1.0000
#    Year: 2020 | Venue:
#
# 35. Title: Machine Learning and Algorithmic Trading: In Fixed Income Markets...
#    Final Score: 0.6915
#    Dense: 0.8327 | Sparse: 0.3061 | Boost: 1.0000
#    Year: 2013 | Venue:
#
# 36. Title: A machine learning framework for classifying invulnerabilites [sic] and predicti...
#    Final Score: 0.6895
#    Dense: 0.8187 | Sparse: 0.3277 | Boost: 1.0000
#    Year: 2009 | Venue:
#
# 37. Title: A Machine Learning Approach for Annual Rainfall Prediction Using Linear Regressi...
#    Final Score: 0.6848
#    Dense: 0.7741 | Sparse: 0.4011 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 38. Title: A Machine Learning Analysis of the Geographic Localization of Knowledge Flows...
#    Final Score: 0.6837
#    Dense: 0.8219 | Sparse: 0.3019 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 39. Title: Machine-Learning Informed Representations for Grain Boundary Structures...
#    Final Score: 0.6815
#    Dense: 0.7582 | Sparse: 0.4220 | Boost: 1.0000
#    Year: 2019 | Venue: Front. Mater.
#
# 40. Title: Machine Learning based Network Anomaly Detection for IoT environments...
#    Final Score: 0.6793
#    Dense: 0.7888 | Sparse: 0.3533 | Boost: 1.0000
#    Year: 2018 | Venue:
#
# 41. Title: Machine Learning Based On Big Data Extraction of Massive Educational Knowledge...
#    Final Score: 0.6773
#    Dense: 0.7547 | Sparse: 0.4151 | Boost: 1.0000
#    Year: 2017 | Venue: iJET
#
# 42. Title: Machine Learning and Cybernetics...
#    Final Score: 0.6748
#    Dense: 0.7443 | Sparse: 0.4275 | Boost: 1.0000
#    Year: 2014 | Venue: Communications in Computer and Information Science
#
# 43. Title: Machine Learning Classification for Assessing the Degree of Stenosis and Blood F...
#    Final Score: 0.6730
#    Dense: 0.8000 | Sparse: 0.3099 | Boost: 1.0000
#    Year: 2019 | Venue: Sensors
#
# 44. Title: A Machine Learning Approach to the Residential Relocation Distance of Households...
#    Final Score: 0.6723
#    Dense: 0.8024 | Sparse: 0.3028 | Boost: 1.0000
#    Year: 2018 | Venue:
#
# 45. Title: Using Machine Learning To Identify Factors That Govern Amorphization of Irradiat...
#    Final Score: 0.6707
#    Dense: 0.6797 | Sparse: 0.5429 | Boost: 1.0000
#    Year: 2016 | Venue:
#
# 46. Title: Machine Learning and Information Retrieval (Abstract)...
#    Final Score: 0.6693
#    Dense: 0.7608 | Sparse: 0.3761 | Boost: 1.0000
#    Year: 1995 | Venue: ICML
#
# 47. Title: Machine-learning-integrated load scheduling for reduced peak power demand...
#    Final Score: 0.6689
#    Dense: 0.7849 | Sparse: 0.3267 | Boost: 1.0000
#    Year: 2015 | Venue: IEEE Transactions on Consumer Electronics
#
# 48. Title: A machine learning approach to extract contributions relevant to sustainable dev...
#    Final Score: 0.6688
#    Dense: 0.8448 | Sparse: 0.2064 | Boost: 1.0000
#    Year: 2018 | Venue:
#
# 49. Title: Machine Learning in Updating Predictive Models of Planning and Scheduling Transp...
#    Final Score: 0.6672
#    Dense: 0.7722 | Sparse: 0.3461 | Boost: 1.0000
#    Year: 1997 | Venue:
#
# 50. Title: Machine Learning goes Measure Management: Leveraging Anomaly Detection and Parts...
#    Final Score: 0.6662
#    Dense: 0.7338 | Sparse: 0.4196 | Boost: 1.0000
#    Year: 2019 | Venue: Wirtschaftsinformatik
#
# 51. Title: MACHINE LEARNING AND ADVANCED STATISTICS IN ASTRONOMY:TWO APPLICATIONS...
#    Final Score: 0.6651
#    Dense: 0.7794 | Sparse: 0.3249 | Boost: 1.0000
#    Year: 2015 | Venue:
#
# 52. Title: A Machine Learning Management Model for QoE Enhancement in Next-Generation Wirel...
#    Final Score: 0.6628
#    Dense: 0.7923 | Sparse: 0.2913 | Boost: 1.0000
#    Year: 2018 | Venue: 2018 ITU Kaleidoscope: Machine Learning for a 5G Future (ITU K)
#
# 53. Title: A Machine Learning Based System for Analgesic Drug Delivery...
#    Final Score: 0.6610
#    Dense: 0.7373 | Sparse: 0.3955 | Boost: 1.0000
#    Year: 2017 | Venue: SOCO-CISIS-ICEUTE
#
# 54. Title: Machine Learning for Cultural Heritage: A Survey...
#    Final Score: 0.6605
#    Dense: 0.7852 | Sparse: 0.2980 | Boost: 1.0000
#    Year: 2020 | Venue: Pattern Recognit. Lett.
#
# 55. Title: A Machine Learning System for Identifying Animate Motion...
#    Final Score: 0.6589
#    Dense: 0.7347 | Sparse: 0.3936 | Boost: 1.0000
#    Year: 2002 | Venue:
#
# 56. Title: Machine Learning Methods for Anomaly Detection in BACnet Networks...
#    Final Score: 0.6584
#    Dense: 0.7932 | Sparse: 0.2751 | Boost: 1.0000
#    Year: 2016 | Venue: J. Univers. Comput. Sci.
#
# 57. Title: Machine Learning HW 2...
#    Final Score: 0.6579
#    Dense: 0.7743 | Sparse: 0.3111 | Boost: 1.0000
#    Year: 2002 | Venue:
#
# 58. Title: A machine learning technique in a multi-agent framework for online outliers dete...
#    Final Score: 0.6564
#    Dense: 0.7963 | Sparse: 0.2621 | Boost: 1.0000
#    Year: 2015 | Venue: IECON 2015 - 41st Annual Conference of the IEEE Industrial Electronics Society
#
# 59. Title: Machine learning approach identifies new pathways associated with demyelination ...
#    Final Score: 0.6561
#    Dense: 0.8098 | Sparse: 0.2339 | Boost: 1.0000
#    Year: 2010 | Venue: Journal of cellular and molecular medicine
#
# 60. Title: A Machine Learning Approach to March Madness...
#    Final Score: 0.6552
#    Dense: 0.8246 | Sparse: 0.2014 | Boost: 1.0000
#    Year: 2014 | Venue:
#
# 61. Title: Machine learning for ranking day-ahead decisions in the context of short-term op...
#    Final Score: 0.6539
#    Dense: 0.7398 | Sparse: 0.3666 | Boost: 1.0000
#    Year: 2020 | Venue:
#
# 62. Title: Machine learning algorithm to predict coronary artery calcification in asymptoma...
#    Final Score: 0.6534
#    Dense: 0.7985 | Sparse: 0.2476 | Boost: 1.0000
#    Year: 2019 | Venue: 2019 IEEE Healthcare Innovations and Point of Care Technologies, (HI-POCT)
#
# 63. Title: Machine Learning Models for Directed Curation of Design Solution Space...
#    Final Score: 0.6532
#    Dense: 0.7737 | Sparse: 0.2965 | Boost: 1.0000
#    Year: 2017 | Venue:
#
# 64. Title: Machine learning approach for ship detection using remotely sensed images...
#    Final Score: 0.6509
#    Dense: 0.8274 | Sparse: 0.1815 | Boost: 1.0000
#    Year: 2017 | Venue: 2017 2nd International Conference for Convergence in Technology (I2CT)
#
# 65. Title: Does Machine Learning Really Work?...
#    Final Score: 0.6496
#    Dense: 0.5836 | Sparse: 0.6647 | Boost: 1.0000
#    Year: 1997 | Venue: AI Mag.
#
# 66. Title: Application of machine learning in the diagnosis of axial spondyloarthritis...
#    Final Score: 0.6488
#    Dense: 0.5472 | Sparse: 0.7350 | Boost: 1.0000
#    Year: 2019 | Venue: Current opinion in rheumatology
#
# 67. Title: Machine Learning Framework for Classification in Medicine and Biology...
#    Final Score: 0.6479
#    Dense: 0.7657 | Sparse: 0.2947 | Boost: 1.0000
#    Year: 2009 | Venue: CPAIOR
#
# 68. Title: Using a Machine Learning Algorithm to Create a Computational Artwork: Variable...
#    Final Score: 0.6478
#    Dense: 0.5211 | Sparse: 0.7840 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 69. Title: Machine learning methods for estimating probability density functions of transmi...
#    Final Score: 0.6472
#    Dense: 0.8145 | Sparse: 0.1949 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 70. Title: Machine-Learning Space Applications on SmallSat Platforms with TensorFlow...
#    Final Score: 0.6465
#    Dense: 0.7513 | Sparse: 0.3190 | Boost: 1.0000
#    Year: 2018 | Venue:
#
# 71. Title: Machine learning based imputation techniques for estimating phylogenetic trees f...
#    Final Score: 0.6442
#    Dense: 0.7692 | Sparse: 0.2757 | Boost: 1.0000
#    Year: 2020 | Venue: BMC Genomics
#
# 72. Title: Machine Learning Based Error Prediction for Spray Painting Applications...
#    Final Score: 0.6442
#    Dense: 0.7407 | Sparse: 0.3325 | Boost: 1.0000
#    Year: 2016 | Venue:
#
# 73. Title: A Machine Learning Approach Predicts Tissue-Specific Drug Adverse Events...
#    Final Score: 0.6440
#    Dense: 0.8211 | Sparse: 0.1712 | Boost: 1.0000
#    Year: 2018 | Venue:
#
# 74. Title: ANALYSIS OF MACHINE LEARNING TECHNIQUES FOR GENE SELECTION AND CLASSIFICATION OF...
#    Final Score: 0.6424
#    Dense: 0.7008 | Sparse: 0.4063 | Boost: 1.0000
#    Year: 2013 | Venue:
#
# 75. Title: From machine learning to deep learning: progress in machine intelligence for rat...
#    Final Score: 0.6421
#    Dense: 0.6349 | Sparse: 0.5374 | Boost: 1.0000
#    Year: 2017 | Venue: Drug discovery today
#
# 76. Title: Machine learning in physics: The pitfalls of poisoned training sets...
#    Final Score: 0.6416
#    Dense: 0.7656 | Sparse: 0.2741 | Boost: 1.0000
#    Year: 2020 | Venue:
#
# 77. Title: Machine learning approaches outperform distance- and tree-based methods for DNA ...
#    Final Score: 0.6416
#    Dense: 0.7877 | Sparse: 0.2299 | Boost: 1.0000
#    Year: 2019 | Venue: Planta
#
# 78. Title: A machine learning based approach of robust parameter design...
#    Final Score: 0.6413
#    Dense: 0.7612 | Sparse: 0.2819 | Boost: 1.0000
#    Year: 2006 | Venue:
#
# 79. Title: A Machine Learning Approach for Predicting the Sunspot of Solar Cycle...
#    Final Score: 0.6410
#    Dense: 0.8326 | Sparse: 0.1381 | Boost: 1.0000
#    Year: 2020 | Venue: 2020 11th International Conference on Computing, Communication and Networking Technologies (ICCCNT)
#
# 80. Title: Using Machine Learning to Classify Bioactivity for 3486 Per- and Polyfluoroalkyl...
#    Final Score: 0.6408
#    Dense: 0.6782 | Sparse: 0.4463 | Boost: 1.0000
#    Year: 2019 | Venue: Environmental science & technology
#
# 81. Title: MACHINE LEARNING FOR TRAJECTORIES OF PARAMETRIC NONLINEAR DYNAMICAL SYSTEMS...
#    Final Score: 0.6406
#    Dense: 0.7710 | Sparse: 0.2602 | Boost: 1.0000
#    Year: 2020 | Venue:
#
# 82. Title: Machine learning from experience feedback on accidents in transport...
#    Final Score: 0.6392
#    Dense: 0.7647 | Sparse: 0.2679 | Boost: 1.0000
#    Year: 2016 | Venue: 2016 7th International Conference on Sciences of Electronics, Technologies of Information and Telecommunications (SETIT)
#
# 83. Title: USING MACHINE LEARNING FOR FEATURE DETECTION IN TRANSMISSION ELECTRON MICROSCOPY...
#    Final Score: 0.6381
#    Dense: 0.6755 | Sparse: 0.4427 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 84. Title: Machine Learning through Evolution: Training Algorithms through Competition...
#    Final Score: 0.6371
#    Dense: 0.7453 | Sparse: 0.2997 | Boost: 1.0000
#    Year: 2013 | Venue:
#
# 85. Title: A Machine Learning-Driven Approach to Computational Physiological Modeling of Sk...
#    Final Score: 0.6360
#    Dense: 0.7626 | Sparse: 0.2614 | Boost: 1.0000
#    Year: 2017 | Venue: ICIAR
#
# 86. Title: A Machine Learning Based Framework for Sub-Resolution Assist Feature Generation...
#    Final Score: 0.6358
#    Dense: 0.7302 | Sparse: 0.3257 | Boost: 1.0000
#    Year: 2016 | Venue: ISPD '16
#
# 87. Title: Machine Learning of Two-Dimensional Spectroscopic Data...
#    Final Score: 0.6356
#    Dense: 0.7466 | Sparse: 0.2921 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 88. Title: Application of Machine Learning to Financial Trading...
#    Final Score: 0.6352
#    Dense: 0.5330 | Sparse: 0.7182 | Boost: 1.0000
#    Year: 2018 | Venue:
#
# 89. Title: Machine Learning Framework: Predicting Protein Structural Features...
#    Final Score: 0.6352
#    Dense: 0.7542 | Sparse: 0.2755 | Boost: 1.0000
#    Year: 2018 | Venue:
#
# 90. Title: A machine learning approach to radiogenomics of breast cancer: a study of 922 su...
#    Final Score: 0.6345
#    Dense: 0.7934 | Sparse: 0.1949 | Boost: 1.0000
#    Year: 2018 | Venue: British Journal of Cancer
#
# 91. Title: Machine Learning and Geographic Information Systems for large-scale mapping of r...
#    Final Score: 0.6345
#    Dense: 0.7584 | Sparse: 0.2649 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 92. Title: Machine-learning-based Classification of Lower-grade gliomas and High-grade glio...
#    Final Score: 0.6342
#    Dense: 0.7643 | Sparse: 0.2520 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 93. Title: Machine learning for signal processing: geometry, kernels, and symbolic sequence...
#    Final Score: 0.6333
#    Dense: 0.7637 | Sparse: 0.2503 | Boost: 1.0000
#    Year: 2010 | Venue:
#
# 94. Title: Machine learning and statistical methods for clustering single-cell RNA-sequenci...
#    Final Score: 0.6330
#    Dense: 0.7750 | Sparse: 0.2264 | Boost: 1.0000
#    Year: 2020 | Venue: Briefings Bioinform.
#
# 95. Title: Machine Learning Approach for Blockage Detection and Localization using Pressure...
#    Final Score: 0.6325
#    Dense: 0.8068 | Sparse: 0.1614 | Boost: 1.0000
#    Year: 2020 | Venue: 2020 IEEE International Conference on Computing, Power and Communication Technologies (GUCON)
#
# 96. Title: A Machine Learning Approach to Predicting Blood Glucose Levels for Diabetes Mana...
#    Final Score: 0.6251
#    Dense: 0.8210 | Sparse: 0.1081 | Boost: 1.0000
#    Year: 2014 | Venue: AAAI Workshop: Modern Artificial Intelligence for Health Analytics
#
# 97. Title: Application of Machine Learning and Big data Analytics in Pharmacovigilance and ...
#    Final Score: 0.6245
#    Dense: 0.5730 | Sparse: 0.6024 | Boost: 1.0000
#    Year: 2019 | Venue: 2019 2nd International Conference on Intelligent Computing, Instrumentation and Control Technologies (ICICICT)
#
# 98. Title: Machine Learning to Differentiate Between Positive and Negative Emotions Using P...
#    Final Score: 0.6232
#    Dense: 0.7298 | Sparse: 0.2845 | Boost: 1.0000
#    Year: 2015 | Venue: Front. Psychol.
#
# 99. Title: Machine Learning Based Crack Mode Classification From Unlabeled Acoustic Emissio...
#    Final Score: 0.6228
#    Dense: 0.7419 | Sparse: 0.2589 | Boost: 1.0000
#    Year: 2019 | Venue:
#
# 100. Title: Research on Machine Learning Prediction of Air Quality Index Based on SPSS...
#    Final Score: 0.6224
#    Dense: 0.8093 | Sparse: 0.1227 | Boost: 1.0000
#    Year: 2020 | Venue: 2020 International Conference on Computer Network, Electronic and Automation (ICCNEA)

# %%
# Example 1: Hard filters (exclude unwanted documents)
hard_filters = {
    "min_year": 2018,  # Only papers from 2018 onwards
    "excluded_venues": ["workshop"]  # Exclude workshop papers
}

print("=== QUERY WITH HARD FILTERS ===")
print(f"Filters: Only papers from 2018+, exclude workshops")

filtered_results = hybrid_retrieve(
    query=query,
    components=ft_components,
    user_filters=hard_filters,
    top_k=5
)

print(f"\nResults with hard filters:")
for i, doc in enumerate(filtered_results):
    year = doc['metadata'].get('year', 'N/A')
    venue = doc['metadata'].get('venue', 'N/A')
    print(f"{i+1}. {doc['metadata']['title'][:60]}...")
    print(f"   Year: {year} | Venue: {venue} | Score: {doc['scores']['final_score']:.4f}")
# Out:
# === QUERY WITH HARD FILTERS ===
# Filters: Only papers from 2018+, exclude workshops
# Retrieving top-5 documents for query: 'what is machine learning...'
# Encoding query...
# Computing dense similarities (top-1000)...
# Applying hard filters...
# 334 candidates after filtering
# Computing sparse similarities...
# Applying metadata boosting...
# Combining scores...
# Retrieved 5 documents
#
# Results with hard filters:
# 1. Machine Learning for IoT...
#    Year: 2020 | Venue:  | Score: 0.7834
# 2. Machine Learning Techniques for Wireless-Powered Ambient Bac...
#    Year: 2020 | Venue: Convergence of Artificial Intelligence and the Internet of Things | Score: 0.7776
# 3. Machine learning in the optimization of robotics in the oper...
#    Year: 2020 | Venue: Current opinion in urology | Score: 0.7762
# 4. Machine Learning for Mathematical Software...
#    Year: 2019 | Venue:  | Score: 0.7602
# 5. Machine Learning Algorithms for Stratigraphy Classification ...
#    Year: 2019 | Venue:  | Score: 0.7576

# %%
# Example 2: Soft boosting (prefer certain documents)
boost_filters = {
    "venue": "NIPS",  # Boost NIPS papers
    "field": "machine learning",  # Boost ML papers
    "year_after": 2019  # Boost recent papers
}

print("\n=== QUERY WITH SOFT BOOSTING ===")
print(f"Boosting: NIPS papers, ML field, recent papers (2019+)")

boosted_results = hybrid_retrieve(
    query=query,
    components=ft_components,
    user_filters=boost_filters,
    top_k=5
)

print(f"\nResults with boosting:")
for i, doc in enumerate(boosted_results):
    year = doc['metadata'].get('year', 'N/A')
    venue = doc['metadata'].get('venue', 'N/A')
    fields = doc['metadata'].get('fieldsOfStudy', [])
    print(f"{i+1}. {doc['metadata']['title'][:60]}...")
    print(f"   Year: {year} | Venue: {venue}")
    print(f"   Fields: {fields[:2]}...")  # Show first 2 fields
    print(f"   Score: {doc['scores']['final_score']:.4f} (Boost: {doc['scores']['boost_score']:.4f})")
# Out:
# === QUERY WITH SOFT BOOSTING ===
# Boosting: NIPS papers, ML field, recent papers (2019+)
# Retrieving top-5 documents for query: 'what is machine learning...'
# Encoding query...
# Computing dense similarities (top-1000)...
# Computing sparse similarities...
# Applying metadata boosting...
# Combining scores...
# Retrieved 5 documents
#
# Results with boosting:
# 1. Machine Learning for IoT...
#    Year: 2020 | Venue:
#    Fields: ['Computer Science']...
#    Score: 0.7854 (Boost: 1.0200)
# 2. Machine Learning Techniques for Wireless-Powered Ambient Bac...
#    Year: 2020 | Venue: Convergence of Artificial Intelligence and the Internet of Things
#    Fields: ['Computer Science']...
#    Score: 0.7796 (Boost: 1.0200)
# 3. Machine learning in the optimization of robotics in the oper...
#    Year: 2020 | Venue: Current opinion in urology
#    Fields: ['Medicine']...
#    Score: 0.7782 (Boost: 1.0200)
# 4. Machine Learning Applications to Resting-State Functional MR...
#    Year: 2017 | Venue: Neuroimaging clinics of North America
#    Fields: ['Medicine']...
#    Score: 0.7669 (Boost: 1.0000)
# 5. A study on machine learning web service...
#    Year: 2017 | Venue: 2017 International Conference on Information and Communication Technology Convergence (ICTC)
#    Fields: ['Computer Science']...
#    Score: 0.7622 (Boost: 1.0000)

# %%
# Analyze scoring components without metadata boosting 

def analyze_scores(results, model_name):
    print(f"\n=== SCORE ANALYSIS: {model_name} ===")
    
    dense_scores = [doc['scores']['dense_score'] for doc in results]
    sparse_scores = [doc['scores']['sparse_score'] for doc in results]
    boost_scores = [doc['scores']['boost_score'] for doc in results]
    final_scores = [doc['scores']['final_score'] for doc in results]
    
    print(f"Dense scores  - Min: {min(dense_scores):.4f}, Max: {max(dense_scores):.4f}, Avg: {np.mean(dense_scores):.4f}")
    print(f"Sparse scores - Min: {min(sparse_scores):.4f}, Max: {max(sparse_scores):.4f}, Avg: {np.mean(sparse_scores):.4f}")
    print(f"Boost scores  - Min: {min(boost_scores):.4f}, Max: {max(boost_scores):.4f}, Avg: {np.mean(boost_scores):.4f}")
    print(f"Final scores  - Min: {min(final_scores):.4f}, Max: {max(final_scores):.4f}, Avg: {np.mean(final_scores):.4f}")
    
    # Show scoring weights
    config = ft_components['config']
    print(f"\nScoring weights: Dense={config['scoring']['dense_weight']}, Sparse={config['scoring']['sparse_weight']}, Boost={config['scoring']['boost_weight']}")

# Analyze both models
analyze_scores(base_results, "BASE MODEL")
analyze_scores(ft_results, "FINE-TUNED MODEL")
# Out:
# === SCORE ANALYSIS: BASE MODEL ===
# Dense scores  - Min: 0.5843, Max: 0.6380, Avg: 0.6129
# Sparse scores - Min: 0.7134, Max: 0.8464, Avg: 0.7524
# Boost scores  - Min: 1.0000, Max: 1.0000, Avg: 1.0000
# Final scores  - Min: 0.6762, Max: 0.7191, Avg: 0.6935
#
# Scoring weights: Dense=0.6, Sparse=0.3, Boost=0.1
#
# === SCORE ANALYSIS: FINE-TUNED MODEL ===
# Dense scores  - Min: 0.5211, Max: 0.8749, Avg: 0.7594
# Sparse scores - Min: 0.1081, Max: 0.7840, Avg: 0.4056
# Boost scores  - Min: 1.0000, Max: 1.0000, Avg: 1.0000
# Final scores  - Min: 0.6224, Max: 0.7834, Avg: 0.6773
#
# Scoring weights: Dense=0.6, Sparse=0.3, Boost=0.1
